# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       32880792 kB
# MemFree:        26625928 kB
# MemAvailable:   31544244 kB
# Buffers:          895244 kB
# Cached:          4093792 kB
# SwapCached:            0 kB
# Active:          1186640 kB
# Inactive:        4446212 kB
# Active(anon):        612 kB
# Inactive(anon):   644128 kB
# Active(file):    1186028 kB
# Inactive(file):  3802084 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               964 kB
# Writeback:             0 kB
# AnonPages:        643932 kB
# Mapped:           241436 kB
# Shmem:               912 kB
# KReclaimable:     396112 kB
# Slab:             457476 kB
# SReclaimable:     396112 kB
# SUnreclaim:        61364 kB
# KernelStack:        3936 kB
# PageTables:         4756 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:    16440396 kB
# Committed_AS:    2252908 kB
# VmallocTotal:   34359738367 kB
# ...
